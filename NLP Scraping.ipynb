# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# %%
url = 'https://www.sunstar.com.ph/morearticles/baguio/local-news'

driver = webdriver.Chrome()
driver.get(url)

# %%
articles = driver.find_elements(By.CLASS_NAME, 'col-md-3')
list_articles = []
for article in articles:
    title = article.find_element(By.CLASS_NAME, 'article-title').text
    link = article.find_element(By.TAG_NAME, 'a')
    date = article.find_element(By.CLASS_NAME, 'article-date').text

    newl = link.get_attribute('href')

    driver.implicitly_wait(10)
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[1])
    driver.get(newl)
    driver.implicitly_wait(10)

    content = driver.find_element(By.CLASS_NAME, 'article-body').text

    per_article = {
        'title': title,
        'date': date,
        'content': content
    }

    list_articles.append(per_article)
    df = pd.DataFrame(list_articles)

    driver.close()
    driver.switch_to.window(driver.window_handles[0])

print(df)
# Out:
#                                                 title               date  \
# 0   Aboitiz launches cold storage project for smal...     MARCH 17, 2023
# 1   DSWD, Abra LGU extend cash aid to 2,800 solo p...     MARCH 12, 2023
# 2   2 Cordilleran women among government service e...     MARCH 11, 2023
# 3   DILG issues guidelines on Cordi LGUs to boost ...     MARCH 10, 2023
# 4   RGADC highlights collective action for women e...     MARCH 09, 2023
# 5     2023 Kawayan Fest Trade Fair open until March 9     MARCH 08, 2023
# 6   Cordillera IP agency told to furnish city list...     MARCH 06, 2023
# 7   Imee, LGU officials lead groundbreaking of new...     MARCH 05, 2023
# 8   Miss Apayao is among 2023 Miss Universe–PH Top 40     MARCH 04, 2023
# 9   Panagbenga proof of Baguio resilience from crisis  FEBRUARY 26, 2023
# 10  'Bigger, better' Panagbenga to return after 2-...  DECEMBER 12, 2022
# 11  DOLE allots P73-M for quake-hit areas in Iloco...    AUGUST 10, 2022
# 12    Peña elected as LMP Negros Occidental president    AUGUST 05, 2022
# 13  LGBTQ voter registration to be prioritized on ...      JULY 08, 2022
# 14  Baguio tags 5,000 pine trees being preserved a...      JUNE 21, 2022
# 15  Independence Day job fair in Baguio to offer o...      JUNE 07, 2022
# 16  Cagayan farmers celebrate increased yellow cor...       MAY 23, 2022
# 17  1,700 fisherfolk march on Earth Day to stop dr...     APRIL 22, 2022
# 18            Baguio nears month sans Covid-19 deaths     APRIL 19, 2022
# 19  No spike in Covid-19 cases despite Panagbenga:...     APRIL 06, 2022
#
#                                               content
# 0   IN LINE with its “great transformation” to bec...
# 1   DEPARTMENT of Social Welfare and Development (...
# 2   TWO Cordilleran women are among the awardees o...
# 3   THE Department of the Interior and Local Gover...
# 4   WITH the theme, "WE for gender equality and in...
# 5   VARIOUS Abrenian local products and native del...
# 6   CITY officials recently requested the Cordille...
# 7   LA TRINIDAD town, Benguet will have a new muni...
# 8   THE Miss Universe–Philippines Organization ann...
# 9   AFTER a three-year hiatus, the revival of the ...
# 10  BAGUIO CITY – The Baguio Flower Festival Found...
# 11  SAN FERNANDO CITY, La Union – The Department o...
# 12  PULUPANDAN town Mayor Miguel Antonio Peña was ...
# 13  BAGUIO CITY – Members of the lesbian, gay, bis...
# 14  BAGUIO CITY – The city government has already ...
# 15  BAGUIO CITY – The city government on Monday in...
# 16  LAUNCHED in October 2021, the yellow corn proj...
# 17  ONE thousand seven hundred fisherfolk from mor...
# 18  BAGUIO CITY – The local government here said t...
# 19  BAGUIO CITY – Local health officials are not s...

# %%
url = 'https://www.sunstar.com.ph/morearticles/baguio/local-news?pgno=2'
driver.get(url)

# %%
articles = driver.find_elements(By.CLASS_NAME, 'col-md-3')
for article in articles:
    title = article.find_element(By.CLASS_NAME, 'article-title').text
    link = article.find_element(By.TAG_NAME, 'a')
    date = article.find_element(By.CLASS_NAME, 'article-date').text

    newl = link.get_attribute('href')

    driver.implicitly_wait(10)
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[1])
    driver.get(newl)
    driver.implicitly_wait(10)

    content = driver.find_element(By.CLASS_NAME, 'article-body').text

    per_article = {
        'title': title,
        'date': date,
        'content': content
    }

    list_articles.append(per_article)
    df = pd.DataFrame(list_articles)

    driver.close()
    driver.switch_to.window(driver.window_handles[0])

print(df)
# Out:
#                                                 title                date  \
# 0   Aboitiz launches cold storage project for smal...      MARCH 17, 2023
# 1   DSWD, Abra LGU extend cash aid to 2,800 solo p...      MARCH 12, 2023
# 2   2 Cordilleran women among government service e...      MARCH 11, 2023
# 3   DILG issues guidelines on Cordi LGUs to boost ...      MARCH 10, 2023
# 4   RGADC highlights collective action for women e...      MARCH 09, 2023
# 5     2023 Kawayan Fest Trade Fair open until March 9      MARCH 08, 2023
# 6   Cordillera IP agency told to furnish city list...      MARCH 06, 2023
# 7   Imee, LGU officials lead groundbreaking of new...      MARCH 05, 2023
# 8   Miss Apayao is among 2023 Miss Universe–PH Top 40      MARCH 04, 2023
# 9   Panagbenga proof of Baguio resilience from crisis   FEBRUARY 26, 2023
# 10  'Bigger, better' Panagbenga to return after 2-...   DECEMBER 12, 2022
# 11  DOLE allots P73-M for quake-hit areas in Iloco...     AUGUST 10, 2022
# 12    Peña elected as LMP Negros Occidental president     AUGUST 05, 2022
# 13  LGBTQ voter registration to be prioritized on ...       JULY 08, 2022
# 14  Baguio tags 5,000 pine trees being preserved a...       JUNE 21, 2022
# 15  Independence Day job fair in Baguio to offer o...       JUNE 07, 2022
# 16  Cagayan farmers celebrate increased yellow cor...        MAY 23, 2022
# 17  1,700 fisherfolk march on Earth Day to stop dr...      APRIL 22, 2022
# 18            Baguio nears month sans Covid-19 deaths      APRIL 19, 2022
# 19  No spike in Covid-19 cases despite Panagbenga:...      APRIL 06, 2022
# 20  Panagbenga weekend draws 45K tourists amid pan...      MARCH 30, 2022
# 21  12-hr power interruption in Ilocos Norte areas...      MARCH 30, 2022
# 22  World-renowned Palaui Island reopens after 2 y...      MARCH 09, 2022
# 23  Bacolod City eyes requiring negative swab test...    JANUARY 11, 2022
# 24  2 firecracker injuries end Baguio's 2-year zer...    JANUARY 04, 2022
# 25  Baguio to welcome New Year with community fire...   DECEMBER 31, 2021
# 26       Baguio sends P5-M aid to 44 typhoon-hit LGUs   DECEMBER 31, 2021
# 27  Cordillera farmers benefit from P556-M agri as...   NOVEMBER 05, 2021
# 28        Cagayanos receive P199.5M worth of machines   NOVEMBER 05, 2021
# 29           Cops build restroom for sitio in Benguet   NOVEMBER 01, 2021
# 30          Sagada cancels annual Nov. 1 'Panag-apoy'    OCTOBER 28, 2021
# 31  Nas Academy reconciles with Apo Whang-Od, Kali...    OCTOBER 24, 2021
# 32  Baguio mulls allowing entry of fully vaccinate...    OCTOBER 20, 2021
# 33                 Baguio cemeteries closed for Undas    OCTOBER 15, 2021
# 34  Baguio imposes liquor ban, tighter curbs as ca...  SEPTEMBER 10, 2021
# 35  More than 7.5K tourism workers in Baguio recei...  SEPTEMBER 02, 2021
# 36            2nd body in Benguet landslide retrieved     AUGUST 20, 2021
# 37  Responders continue search for 2 missing Itogo...     AUGUST 19, 2021
# 38  Baguio locating close contacts of 2 Delta vari...     AUGUST 17, 2021
# 39               PMA moves entrance exam to September     AUGUST 14, 2021
#
#                                               content
# 0   IN LINE with its “great transformation” to bec...
# 1   DEPARTMENT of Social Welfare and Development (...
# 2   TWO Cordilleran women are among the awardees o...
# 3   THE Department of the Interior and Local Gover...
# 4   WITH the theme, "WE for gender equality and in...
# 5   VARIOUS Abrenian local products and native del...
# 6   CITY officials recently requested the Cordille...
# 7   LA TRINIDAD town, Benguet will have a new muni...
# 8   THE Miss Universe–Philippines Organization ann...
# 9   AFTER a three-year hiatus, the revival of the ...
# 10  BAGUIO CITY – The Baguio Flower Festival Found...
# 11  SAN FERNANDO CITY, La Union – The Department o...
# 12  PULUPANDAN town Mayor Miguel Antonio Peña was ...
# 13  BAGUIO CITY – Members of the lesbian, gay, bis...
# 14  BAGUIO CITY – The city government has already ...
# 15  BAGUIO CITY – The city government on Monday in...
# 16  LAUNCHED in October 2021, the yellow corn proj...
# 17  ONE thousand seven hundred fisherfolk from mor...
# 18  BAGUIO CITY – The local government here said t...
# 19  BAGUIO CITY – Local health officials are not s...
# 20  BAGUIO CITY – Amid a global pandemic, the Bagu...
# 21  LAOAG CITY – The National Grid Corporation of ...
# 22  TUGUEGARAO CITY – The world-famous Palaui Isla...
# 23  THE Bacolod City Emergency Operations Center T...
# 24  BAGUIO CITY – The City Epidemiology and Survei...
# 25  BAGUIO CITY – The city government has organize...
# 26  BAGUIO CITY – The city government has sent a P...
# 27  RICE and vegetable farmers in the Cordillera A...
# 28  RICE farmers in Cagayan province received a to...
# 29  WITH the coronavirus disease (Covid-19) pandem...
# 30  BAGUIO CITY – The usual observance of All Sain...
# 31  TINGLAYAN, Kalinga -- Global online learning p...
# 32  BAGUIO CITY – The city government might open i...
# 33  BAGUIO CITY – The city government has ordered ...
# 34  BAGUIO CITY – The city government has ordered ...
# 35  BAGUIO CITY – About 7,510 tourism workers in t...
# 36  BAGUIO CITY – Rescuers have found Friday morni...
# 37  BAGUIO CITY – The Department of Social Welfare...
# 38  BAGUIO CITY – Authorities are locating the fel...
# 39  BAGUIO CITY – The Philippine Military Academy ...

# %%
df.to_csv('SunStar.csv', encoding = 'utf-8', index = False)
